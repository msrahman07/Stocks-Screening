# %%
import numpy as np
import pandas as pd
from datetime import date

# %%
# today = str(date.today())
today = '2023-08-03'

# %%
'america_'+today
# Out:
# 'america_2023-08-03'

# %% [markdown]
# ## Initial Data

# %%
initial_df = pd.read_csv('america_'+today+'.csv')
initial_df = initial_df.drop(columns=['Description'])
initial_df = initial_df[initial_df['Volume'] >= 50000]
change_tracker_df = pd.DataFrame()
change_tracker_df['Ticker'] = initial_df['Ticker']
change_tracker_df['Sum_of_price_change'] = 0
change_tracker_df['Sum_of_volume_change'] = 0
initial_tickers = initial_df['Ticker']
divider = 1

# %%
initial_df
# Out:
#      Ticker     Price  Change %   Volume
# 0         A  125.4950 -1.734398   419164
# 1        AA   33.9900  0.176835   714395
# 3      AAAU   19.1900  0.078227   363599
# 8       AAL   15.8066 -0.899060  8792254
# 11     AAOI    7.8600  6.359946  1125518
# ...     ...       ...       ...      ...
# 7105    ZUO   10.6250 -0.514981   139317
# 7109   ZVSA    0.1699 -0.058824   380993
# 7110    ZWS   29.9400 -1.448321   218033
# 7111   ZYME    7.5000  2.459016    64831
# 7112   ZYNE    0.3510 -4.826464    96744
#
# [2930 rows x 4 columns]

# %% [markdown]
# ## Functions

# %%
# def create_change_tracking_df(prev_df, new_df):
#     change_tracker = pd.DataFrame()
#     change_tracker[]

# %% [markdown]
# ## Calculate change in volume

# %%
#new incoming df
new_df = pd.read_csv('america_'+today+' ('+str(divider)+')'+'.csv')
new_df = new_df.drop(columns=['Description'])
new_df = new_df[new_df['Ticker'].isin(initial_df['Ticker'])]
#==================================================
change_tracker_df['Sum_of_price_change'] += ((new_df['Price'] - initial_df['Price'])/initial_df['Price'])*100
change_tracker_df['Sum_of_volume_change'] += ((new_df['Volume'] - initial_df['Volume'])/initial_df['Volume'])*100
change_tracker_df['Current_price_change'] = ((new_df['Price'] - initial_df['Price'])/initial_df['Price'])*100
change_tracker_df['Current_volume_change'] = ((new_df['Volume'] - initial_df['Volume'])/initial_df['Volume'])*100
change_tracker_df['Avg_price_change'] = change_tracker_df['Sum_of_price_change'] / divider
change_tracker_df['Avg_volume_change'] = change_tracker_df['Sum_of_volume_change'] / divider
change_tracker_df['Volume_diff'] = change_tracker_df['Current_volume_change']-change_tracker_df['Avg_volume_change']
divider += 1
initial_df = new_df
#==================================================
rel_vol_df = pd.DataFrame()
rel_vol_df['Ticker'] = new_df['Ticker']
rel_vol_df['Price'] = new_df['Price']
check = change_tracker_df
rel_vol_df['Price_diff'] = check['Current_price_change'] - check['Avg_price_change']
rel_vol_df['Volume_diff'] = check['Current_volume_change'] - check['Avg_volume_change']
#==================================================

# average volume change
# percentage diff from current volume and average volume change
# change_tracker_df.sort_values(by='Volume_diff', ascending=False)[:50]

# %%
rel_vol_df = change_tracker_df.sort_values(by='Volume_diff', ascending=False)
rel_vol_df = change_tracker_df.reset_index(drop=True)
rel_vol_df.sort_values(by='Volume_diff', ascending=False)[:50]
# Out:
# 2826            2418.379488       3499.948764         723.179900   1695.199588
# 590             2065.314989        870.354594         525.578599   1539.736389
# 284             1714.258171       5848.092231         409.432179   1304.825991
# 525             1351.372201       1752.389702         452.948017    898.424184
# 2378            1277.889190        -27.265729         428.934547    848.954644
# 2823            1008.113197        239.542877         228.842453    779.270744
# 1948            1192.989418        383.893273         414.947950    778.041468
# 2404             826.416516          3.128790         219.221527    607.194989
# 946              678.849192         37.693664         170.333835    508.515358
# 2754             591.683079       3074.743464         108.237312    483.445767
# 2855             536.266067      18620.324493         128.075038    408.191029
# 223              597.540459        235.966539         223.839419    373.701040
# 1963             498.416527          7.612241         139.200736    359.215791
# 2275             328.703926        263.104280         125.353135    203.350791
# 2016             252.026123        555.711496          55.514228    196.511895
# 2436             270.690440          5.936106          78.705786    191.984653
# 483              193.773533        186.132559          32.132072    161.641462
# 187              168.847179        487.893318          29.095206    139.751973
# 2841             138.920506       1418.626754          15.738510    123.181996
# 2518             367.814711         45.490391         255.068346    112.746365
# 1142             564.522066       1756.263498         453.105641    111.416425
# 2809             108.982940       1093.491125          -0.832167    109.815106
# 1265             124.104784        488.914308          21.019992    103.084792
# 2315             113.887092         13.473073          18.654979     95.232113
# 2659             576.532920       2083.603822         484.179355     92.353565
# 2782             188.221789        899.451630         105.644135     82.577655
# 2590              45.660546        480.296849         -29.467824     75.128370
# 31                10.968258        -21.746397         -13.619768     24.588026
# 461               49.963025        442.567673          26.018067     23.944958
# 27                 0.706765        -24.080742         -19.877143     20.583909
# 50                 7.134928        802.129780         -12.955124     20.090053
# 40                 0.149928        -25.075515         -19.688777     19.838705
# 48                 0.027451        -24.626323         -12.807181     12.834632
# 34                 2.961562        -24.008022          -9.575176     12.536737
# 44                 0.045518        -24.928315         -12.433891     12.479409
# 33                 4.643697        157.555749          -6.899304     11.543001
# 52                 3.693935        782.605668          -6.098823      9.792758
# 5                  8.627789         -0.112159           4.025904      4.601885
# 1                  8.932404          0.095521           6.445271      2.487133
# 13                 7.922854         -0.077269           5.650597      2.272257
# 16                 4.983891         -0.060645           3.834080      1.149811
# 3                  5.079985         -0.010438           3.981607      1.098378
# 14                 3.087439          0.002638           2.690291      0.397148
# 18                 1.566591          0.126916           1.234369      0.332222
# 0                  3.348734          0.068734           3.129461      0.219273

# %%
divider
# Out:
# 7

# %%
test = new_df[new_df['Ticker'] == 'RBKB']

# %%
test = change_tracker_df[change_tracker_df['Ticker'] == 'A']

# %%
test
# Out:
#      Ticker  Price  Change %  Volume
# 5336   RBKB   7.01 -1.820728    3235

# %%
check = change_tracker_df[change_tracker_df['Ticker'] == 'A']

# %%
check['Current_volume_change']-check['Avg_volume_change']
# Out:
# 0    1.47685
# dtype: float64

# %%
check = change_tracker_df['Current_volume_change']-change_tracker_df['Avg_volume_change']

# %%
check_df = pd.DataFrame()
check_df['Ticker'] = new_df['Ticker']
check_df['Price'] = new_df['Price']
# check_df['Price_diff'] = change_tracker_df['Current_price_change'] - change_tracker_df['Avg_price_change']
check_df['Volume_diff'] = change_tracker_df['Current_volume_change'] - change_tracker_df['Avg_volume_change']
check_df[200:250]
# Out:
#     Ticker     Price   Volume_diff
# 200   AIXI    8.2000   -459.255356
# 201    AIZ  140.8500   -582.828562
# 202    AJG  221.8900   -154.999595
# 203    AKA    0.5501   -604.888901
# 204   AKAM   93.1000   1535.211341
# 205   AKAN    0.5820   -627.186894
# 206   AKBA    1.6250  15554.407250
# 207   AKLI    1.1300  -1147.352474
# 208   AKRO   44.7600   -494.859222
# 209   AKTS    2.3350   -653.959717
# 210   AKTX    0.2574   -558.096495
# 211    AKU    0.1861   -259.954995
# 212   AKYA    6.6000   -715.075947
# 213     AL   41.5650   -806.309604
# 214    ALB  200.1599  18471.671350
# 215   ALBT    1.3900   -282.771050
# 216   ALCC   10.3400   1832.862796
# 217   ALCO   24.8500   3468.260939
# 218   ALCY   10.2600   -149.722245
# 219   ALDX    8.0000    104.940694
# 220    ALE   56.8650    -87.962402
# 221   ALEC    6.6900    -25.043801
# 222    ALG  179.7800   -203.383919
# 223   ALGM   43.1500    475.949794
# 224   ALGN  365.8050    395.926899
# 225   ALGS    0.8800   -220.580676
# 226   ALGT  115.6800   -272.735184
# 227   ALHC    5.8250   4144.299221
# 228   ALIM    3.1600   -287.081489
# 229   ALIT    8.5550    -72.324366
# 230    ALK   46.9100   -203.549044
# 231   ALKS   27.6500    126.979872
# 232   ALKT   16.6150   -323.198909
# 233    ALL  110.5600     -5.622506
# 234   ALLE  111.8300   2788.136385
# 235   ALLG    2.6485   -346.172449
# 236   ALLK    5.4650  -1040.800422
# 237   ALLO    5.2350   3610.969155
# 238   ALLR    2.4310  -1148.990774
# 239   ALLT    2.3300  -1461.075111
# 240   ALLY   28.8700   -222.959898
# 241   ALNY  191.8000  18519.890027
# 242   ALOT   13.9500   -275.652876
# 243   ALPN   14.0500   -424.632493
# 244   ALPP    1.9900    137.714826
# 245   ALRM   52.3400    360.997548
# 246   ALRN    1.7000   -273.211699
# 247   ALRS   19.6550   -584.130415
# 248   ALSN   59.1000   -553.146448
# 249    ALT    3.0800   -569.241677

# %%
change_tracker_df[change_tracker_df['Ticker'] == 'ALT']
# check_df[check_df['Ticker'] == 'MULN']
# change_tracker_df['Volume_diff'] = change_tracker_df['Current_volume_change'] - change_tracker_df['Avg_volume_change']
# Out:
#     Ticker  Sum_of_price_change  Sum_of_volume_change  Current_price_change  \
# 237    ALT          4553.695533          35282.726565            115.432099
#
#      Current_volume_change  Avg_price_change  Avg_volume_change  Volume_diff
# 237            4648.696407        133.932222        1037.727252  3610.969155

# %%
change_tracker_df[change_tracker_df['Volume_diff'] > 100000]
# Out:
#      Ticker  Sum_of_price_change  Sum_of_volume_change  Current_price_change  \
# 139    AGCO          5765.247388          5.986351e+05            204.383886
# 152    AGNG          9099.832463          1.245903e+05            334.714674
# 182    AIRG          7813.989772          2.284387e+05           6540.217391
# 357     APP          8368.786506          2.985664e+05            175.337187
# 451    ASXC         19644.828562          3.717226e+05             -6.854445
# ...     ...                  ...                   ...                   ...
# 7023   XWEL         38293.937355          1.483936e+06           1071.468401
# 7026    XYL         18747.846292          7.524533e+05            -56.337800
# 7028   XYLG          7749.593379          6.014635e+05           1463.011457
# 7084   ZHDG         76943.598459          9.107893e+05            -27.102585
# 7089   ZING         30312.597508          4.595925e+05            -28.644940
#
#       Current_volume_change  Avg_price_change  Avg_volume_change   Volume_diff
# 139            5.918300e+05        169.566100       17606.915263  5.742231e+05
# 152            1.214250e+05        267.642131        3664.420706  1.177605e+05
# 182            2.056972e+05        229.823229        6718.786356  1.989784e+05
# 357            2.697200e+05        246.140780        8781.366146  2.609386e+05
# 451            2.724487e+05        577.789075       10933.017641  2.615157e+05
# ...                     ...               ...                ...           ...
# 7023           1.237344e+06       1126.292275       43645.183610  1.193698e+06
# 7026           5.926189e+05        551.407244       22130.978030  5.704880e+05
# 7028           2.077346e+05        227.929217       17690.102265  1.900445e+05
# 7084           6.773619e+05       2263.047014       26787.921596  6.505740e+05
# 7089           1.798779e+05        891.546986       13517.427727  1.663605e+05
#
# [170 rows x 8 columns]

# %%
change_tracker_df[change_tracker_df['Ticker'] == 'AGCO']
# Out:
#     Ticker  Sum_of_price_change  Sum_of_volume_change  Current_price_change  \
# 139   AGCO          5765.247388         598635.118929            204.383886
#
#      Current_volume_change  Avg_price_change  Avg_volume_change    Volume_diff
# 139               591830.0          169.5661       17606.915263  574223.084737

# %%
591830.0 - 17606.915263
# Out:
# 574223.084737

# %%
divider
# Out:
# 34

# %%
check_df[check_df['Ticker'] == 'MULN']
# Out:
#      Ticker   Price  Price_diff   Volume_diff
# 4518   MULN  0.1506  -3550.4932  3.466651e+07

# %%
initial_df
# Out:
#      Ticker     Price  Change %   Volume
# 0         A  126.2675 -1.129512   791341
# 1        AA   34.4000  1.385205  1934559
# 2       AAA   24.6900  0.121654    10076
# 3      AAAU   19.1800  0.026076   670771
# 4       AAC   10.6500  0.188147    40849
# ...     ...       ...       ...      ...
# 7486   ZVSA    0.1645 -3.235294   504817
# 7487    ZWS   30.2400 -0.460829   315879
# 7488   ZYME    7.3550  0.478142   116012
# 7489   ZYNE    0.3538 -4.067245   115921
# 7490   ZYXI    8.5300  2.895054    98701
#
# [7491 rows x 4 columns]

# %%
new_df
# Out:
# 0

# %%
# Out:
#      Ticker     Price  Change %   Volume
# 0         A  126.2675 -1.129512   791341
# 1        AA   34.4000  1.385205  1934559
# 2       AAA   24.6900  0.121654    10076
# 3      AAAU   19.1800  0.026076   670771
# 4       AAC   10.6500  0.188147    40849
# ...     ...       ...       ...      ...
# 7486   ZVSA    0.1645 -3.235294   504817
# 7487    ZWS   30.2400 -0.460829   315879
# 7488   ZYME    7.3550  0.478142   116012
# 7489   ZYNE    0.3538 -4.067245   115921
# 7490   ZYXI    8.5300  2.895054    98701
#
# [7491 rows x 4 columns]
