# %%
import pandas as pd
import requests
import json
import time

# %% [markdown]
# ## Get all tickers from nasdaq csv

# %%
# Download the latest file from Nasdaq
nasdaq = pd.read_csv("nasdaq_screener.csv")
symbol_list = nasdaq['Symbol'].values.tolist()
symbol_name = nasdaq['Name'].values.tolist()
price = nasdaq['Last Sale'].values.tolist()

# %%
# get json of all symbols, with name and price as list
symbol_dict_list = []

for i in range(len(symbol_list)):
    if('/' in str(symbol_list[i]) or 
      '^' in str(symbol_list[i])):
        continue
    symbol_dict_list.append({
        'symbol': symbol_list[i],
        'name': symbol_name[i]
    })

# %%
# write the list of dict to json file
# with open("stocks.json", "w") as final:
#    json.dump(symbol_dict_list, final)

# final.close()

# %%
# Out:
# ['Ambev', 'Inc']

# %% [markdown]
# # Get the stocks that are available on WealthSimple

# %%
# change bearer after login
bearer =  "Bearer " # Bearer token goes here
auth = {"authorization": bearer}

# add the ticker at the end of the url
url = "https://trade-service.wealthsimple.com/securities?allow_ineligible_security=true&query="

# Function to check if it's available on WealthSimple
# takes ticker symbol, name and response from WS api call
def check_valid_stock(symbol, response):
    if(response['total_count'] > 0):
        for result in response['results']:
            if(result['stock']['symbol'] == symbol 
               and result['ws_trade_eligible'] == True):
#                and (result['stock']['name'].lower() in name.lower())
#                and (result['stock']['primary_exchange'] == 'NASDAQ'
#                     or result['stock']['primary_exchange'] == 'NYSE')):
                return True
    return False

def search_name_term(name_str):
    name_str_arr = name_str.split(' ')
    
    return (name_str_arr[0]).lower()


search_name_term(symbol_dict_list[0]['name'])
# Out:
# 'agilent'

# %% [markdown]
# ### Check stocks in 100 batch with 1s delay for each stock with 5min break

# %%
# symbol = str(symbol_dict_list[0]['symbol'])
# name = str(symbol_dict_list[0]['name'])
# search_term = search_name_term(name)
# api_url = url + search_term
# response = requests.get(api_url, headers = auth).json()
# if(check_valid_stock(symbol, response)):
#     curated_symbols_list.append(symbol_dict_list[j])
# print(str(j)+": "+symbol)
# response

# %%
# curated_symbols_list = []
# symbol = str(symbol_dict_list[0]['symbol'])
# name = str(symbol_dict_list[0]['name'])
# search_term = search_name_term(name)
# api_url = url + search_term
# response = requests.get(api_url, headers = auth).json()
# response

# %%
# curated_symbols_list

# %%
# # check algorithm works for first 100
# for j in range(0, 100):
#     # check for validity here
#     symbol = str(symbol_dict_list[j]['symbol'])
#     name = str(symbol_dict_list[j]['name'])
#     search_term = search_name_term(name)
#     api_url = url + search_term
#     response = requests.get(api_url, headers = auth).json()

#     if(check_valid_stock(symbol, response)):
#         curated_symbols_list.append(symbol_dict_list[j])
#         print(str(j)+": "+symbol)

#     time.sleep(1)

# %%
len(curated_symbols_list)
# curated_symbols_list[0]
# Out:
# 3733

# %%
# with open("curated_stocks_all.json", "w") as final:
#    json.dump(curated_symbols_list, final)

# final.close()

# %%
# # intervals of 100 stocks
# # starting from 100
# intervals = []

# num = 6749

# while(num < len(symbol_dict_list)):
#     intervals.append(num)
#     num += 100
    
# intervals.append(num)

# # checking 100 stocks' availability at a time
# for i in range(1, len(intervals)):
#     for j in range(intervals[i-1], intervals[i]):
#         # check for validity here
#         symbol = str(symbol_dict_list[j]['symbol'])
#         name = str(symbol_dict_list[j]['name'])
#         search_term = search_name_term(name)
#         api_url = url + search_term
#         response = requests.get(api_url, headers = auth).json()

#         if(check_valid_stock(symbol, response)):
#             curated_symbols_list.append(symbol_dict_list[j])
#             print(str(j)+": "+symbol)

#         time.sleep(1)
#         if(j >= len(symbol_dict_list)-1):
#             break

# %%
nasdaq = pd.read_csv("nasdaq_screener.csv")

# %%
# nasdaq_under_10 = nasdaq[(nasdaq['Last Sale'][1:])]
nasdaq['Last Sale'][0][1:]
# Out:
# '142.54'

# %%
nasdaq['Last Sale'] = nasdaq['Last Sale'].apply(lambda x: float(x))

# %%
nasdaq_under_10 = nasdaq[(nasdaq['Last Sale'] < 11)]

# %%
nasdaq_under_10
# Out:
#      Symbol                                               Name  Last Sale  \
# 2       AAC  Ares Acquisition Corporation Class A Ordinary ...    10.2250
# 3      AACG   ATA Creativity Global American Depositary Shares     1.8400
# 4      AACI            Armada Acquisition Corp. I Common Stock    10.0300
# 5     AACIW                 Armada Acquisition Corp. I Warrant     0.1098
# 6      AADI                  Aadi Bioscience Inc. Common Stock    10.8100
# ...     ...                                                ...        ...
# 7881    ZUO                    Zuora Inc. Class A Common Stock     8.4950
# 7882   ZVIA                     Zevia PBC Class A Common Stock     3.6254
# 7883   ZVSA             ZyVersa Therapeutics Inc. Common Stock     2.2100
# 7885   ZYME                        Zymeworks Inc. Common Stock     8.1500
# 7886   ZYNE          Zynerba Pharmaceuticals Inc. Common Stock     0.4933
#
#       Net Change % Change    Market Cap        Country  IPO Year  Volume  \
# 2        -0.0050  -0.049%  1.278125e+09            NaN    2021.0    3122
# 3        -0.0500  -2.646%  5.773353e+07          China    2008.0    2076
# 4         0.0000    0.00%  2.077163e+08  United States    2021.0      33
# 5         0.0098    9.80%  0.000000e+00  United States    2021.0     200
# 6        -0.0800  -0.735%  2.637112e+08  United States       NaN   12502
# ...          ...      ...           ...            ...       ...     ...
# 7881     -0.0650  -0.759%  1.134932e+09            NaN    2018.0  270358
# 7882     -0.0746  -2.016%  1.626565e+08            NaN    2021.0  112141
# 7883      0.0100   0.455%  2.007105e+07  United States    2022.0    6957
# 7885     -0.2300  -2.745%  5.134775e+08  United States       NaN  131860
# 7886     -0.0257  -4.952%  2.321604e+07  United States    2015.0   21097
#
#                       Sector  \
# 2                    Finance
# 3     Consumer Discretionary
# 4                Industrials
# 5                Industrials
# 6                Health Care
# ...                      ...
# 7881              Technology
# 7882        Consumer Staples
# 7883             Health Care
# 7885             Health Care
# 7886             Health Care
#
#                                                Industry
# 2                                          Blank Checks
# 3                        Service to the Health Industry
# 4                       Consumer Electronics/Appliances
# 5                       Consumer Electronics/Appliances
# 6            Biotechnology: Pharmaceutical Preparations
# ...                                                 ...
# 7881                                       EDP Services
# 7882                                    Specialty Foods
# 7883         Biotechnology: Pharmaceutical Preparations
# 7885  Biotechnology: Biological Products (No Diagnos...
# 7886         Biotechnology: Pharmaceutical Preparations
#
# [3981 rows x 11 columns]

# %%
set_of_available_symbols = []
for stock in curated_symbols_list:
    set_of_available_symbols.append(stock['symbol'])

# %%
len(set_of_available_symbols)
# Out:
# 3733

# %%
nasdaq_available_stocks = nasdaq[(nasdaq['Symbol'].isin(set_of_available_symbols))]

# %%
under_one = nasdaq_available_stocks[nasdaq_available_stocks['Last Sale'] <= 1]

# %%
under_one_high_volume = under_one[under_one['Volume'] > 500000]

# %%
under_one_high_volume
# Out:
#      Symbol                                               Name  Last Sale  \
# 61      ACB                 Aurora Cannabis Inc. Common Shares     0.8402
# 134    ADMP    Adamis Pharmaceuticals Corporation Common Stock     0.2220
# 439     AMV     Atlis Motor Vehicles Inc. Class A Common Stock     0.9200
# 508    APPH                       AppHarvest Inc. Common Stock     0.9950
# 513    APRN      Blue Apron Holdings Inc. Class A Common Stock     0.8600
# 643    ASTR             Astra Space Inc. Class A Common Stock      0.5717
# 648    ASXC                 Asensus Surgical Inc. Common Stock     0.6962
# 721    AULT                    Ault Alliance Inc. Common Stock     0.1157
# 855    BBIG                   Vinco Ventures Inc. Common Stock     0.4870
# 976     BHG              Bright Health Group Inc. Common Stock     0.9100
# 1015   BITF                         Bitfarms Ltd. Common Stock     0.9550
# 1040   BLBX                   Blackboxstocks Inc. Common Stock     0.8110
# 1358   CBIO             Catalyst Biosciences Inc. Common Stock     0.3083
# 1444   CENN     Cenntro Electric Group Limited Ordinary Shares     0.5425
# 1778   CPHI            China Pharma Holdings Inc. Common Stock     0.0693
# 1965   CYBN                           Cybin Inc. Common Shares     0.5020
# 2628   FBIO                 Fortress Biotech Inc. Common Stock     0.7520
# 2682   FFIE  Faraday Future Intelligent Electric Inc. Commo...     0.5340
# 3172   GOEV                    Canoo Inc. Class A Common Stock     0.7338
# 3271    GTE               Gran Tierra Energy Inc. Common Stock     0.8421
# 3378   HGEN                        Humanigen Inc. Common Stock     0.1405
# 3408   HLBZ                   Helbiz Inc. Class A Common stock     0.1150
# 3566   HYMC  Hycroft Mining Holding Corporation Class A Com...     0.3826
# 3622   IDEX                       Ideanomics Inc. Common Stock     0.1343
# 3693   IMPP              Imperial Petroleum Inc. Common Shares     0.1984
# 3719   INFI         Infinity Pharmaceuticals Inc. Common Stock     0.2181
# 4234   LHDX                    Lucira Health Inc. Common Stock     0.5240
# 4274   LKCO            Luokung Technology Corp Ordinary Shares     0.1388
# 4634   MMAT                   Meta Materials Inc. Common Stock     0.6670
# 4807   MULN                Mullen Automotive Inc. Common Stock     0.2400
# 5152   NVOS         Novo Integrated Sciences Inc. Common Stock     0.1190
# 6348    SDC          SmileDirectClub Inc. Class A Common Stock     0.5586
# 6400    SFT       Shift Technologies Inc. Class A Common Stock     0.2076
# 6452   SIDU              Sidus Space Inc. Class A Common Stock     0.7600
# 6490   SKLZ                   Skillz Inc. Class A Common Stock     0.6407
# 6618   SOLO  Electrameccanica Vehicles Corp. Ltd. Common Stock     0.7400
# 6621   SOND          Sonder Holdings Inc. Class A Common Stock     0.9941
# 6843   SYTA                   Siyata Mobile Inc. Common Shares     0.2001
# 7071         Biotechnology: Pharmaceutical Preparations
# 7116                                        Advertising
# 7222                                                NaN
# 7401                                       EDP Services
# 7464        Medicinal Chemicals and Botanical Products
# 7658                                      Durable Goods
# 7724                Beverages (Production/Distribution)
# 7758   Retail: Computer Software & Peripheral Equipment
# 7871                  Pharmaceuticals and Biotechnology

# %%
stocks_stats = pd.read_csv("stocks_stats.csv")

# %%
pe_not_na = stocks_stats[stocks_stats['P/E'].isna()==False]

# %%
pe_not_na = pe_not_na[pe_not_na['P/S'].isna()==False]
pe_not_na = pe_not_na[pe_not_na['P/B'].isna()==False]
pe_not_na = pe_not_na[pe_not_na['EV/EBITDA'].isna()==False]
pe_not_na = pe_not_na[pe_not_na['EV/Revenue'].isna()==False]

# %%
pe_not_na
# Out:
#      Symbol                                               Name     Price  \
# 0         A             Agilent Technologies Inc. Common Stock  140.2100
# 2      AAIC      Arlington Asset Investment Corp Class A (new)    3.0225
# 4      AAME         Atlantic American Corporation Common Stock    2.5400
# 5       AAN         Aarons Holdings Company Inc. Common Stock    12.7000
# 7      AAON                             AAON Inc. Common Stock   90.2850
# ...     ...                                                ...       ...
# 3718    ZTO  ZTO Express (Cayman) Inc. American Depositary ...   24.0050
# 3719    ZTR                      Virtus Total Return Fund Inc.    6.3700
# 3720    ZTS                   Zoetis Inc. Class A Common Stock  168.1600
# 3721   ZUMZ                           Zumiez Inc. Common Stock   23.2300
# 3726   ZYXI                            Zynex Inc. Common Stock   12.6000
#
#        Volume    P/E  PE Percentile    P/B  PB Percentile    P/S  \
# 0      674929  30.97            NaN   7.25            NaN   5.92
# 2       18985  60.80            NaN   0.48            NaN   3.07
# 4         512  17.14            NaN   0.50            NaN   0.25
# 5      349004  26.20            NaN   0.62            NaN   0.21
# 7       78945  65.19            NaN   8.28            NaN   5.70
# ...       ...    ...            ...    ...            ...    ...
# 3718  7674522  21.36            NaN   2.63            NaN   3.95
# 3719   136048  14.55            NaN   1.07            NaN  14.82
# 3720   318989  37.32            NaN  17.63            NaN   9.76
# 3721    81291  10.85            NaN   1.19            NaN   0.46
# 3726    73928  27.28            NaN   7.57            NaN   3.39
#
#       PS Percentile  EV/EBITDA  EV/EBITDA Percentile  EV/Revenue  \
# 0               NaN      21.36                   NaN        6.12
# 2               NaN        NaN                   NaN         NaN
# 4               NaN        NaN                   NaN        0.32
# 5               NaN       1.91                   NaN        0.56
# 7               NaN      30.20                   NaN        5.55
# ...             ...        ...                   ...         ...
# 3718            NaN       2.44                   NaN        0.56
# 3719            NaN        NaN                   NaN         NaN
# 3720            NaN      24.58                   NaN       10.17
# 3721            NaN       6.35                   NaN        0.55
# 3726            NaN      18.29                   NaN        3.33
#
#       EV/Revenue Percentile  RV Score
# 0                       NaN       NaN
# 2                       NaN       NaN
# 4                       NaN       NaN
# 5                       NaN       NaN
# 7                       NaN       NaN
# ...                     ...       ...
# 3718                    NaN       NaN
# 3719                    NaN       NaN
# 3720                    NaN       NaN
# 3721                    NaN       NaN
# 3726                    NaN       NaN
#
# [2266 rows x 15 columns]
