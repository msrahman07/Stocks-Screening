# %% [markdown]
# # Quantitative Value Strategy
# "Value investing" means investing in the stocks that are cheapest relative to common measures of business value (like earnings or assets).
#
# For this project, we're going to build an investing strategy that selects the 50 stocks with the best value metrics. From there, we will calculate recommended trades for an equal-weight portfolio of these 50 stocks.
#
# ## Library Imports
# The first thing we need to do is import the open-source software libraries that we'll be using in this tutorial.

# %%
import numpy as np
import pandas as pd
import math
from scipy import stats
import requests

# %% [markdown]
# ## Importing Our List of Stocks & API Token
# As before, we'll need to import our list of stocks and our API token before proceeding. Make sure the .csv file is still in your working directory and import it with the following command:

# %%
stocks_stats = pd.read_csv("stocks_stats.csv")
stocks_stats_without_NaN = stocks_stats;

# %%
stocks_stats_without_NaN = stocks_stats_without_NaN[stocks_stats_without_NaN['P/E'].isna() == False]
stocks_stats_without_NaN = stocks_stats_without_NaN[stocks_stats_without_NaN['P/S'].isna() == False]
stocks_stats_without_NaN = stocks_stats_without_NaN[stocks_stats_without_NaN['P/B'].isna() == False]
stocks_stats_without_NaN = stocks_stats_without_NaN[stocks_stats_without_NaN['EV/EBITDA'].isna() == False]
stocks_stats_without_NaN = stocks_stats_without_NaN[stocks_stats_without_NaN['EV/Revenue'].isna() == False]
stocks_stats_without_NaN
# Out:
#      Symbol                                               Name    Price  \
# 0         A             Agilent Technologies Inc. Common Stock  140.210
# 5       AAN         Aarons Holdings Company Inc. Common Stock    12.700
# 7      AAON                             AAON Inc. Common Stock   90.285
# 8       AAP                            Advance Auto Parts Inc.  137.650
# 9      AAPL                            Apple Inc. Common Stock  144.485
# ...     ...                                                ...      ...
# 3715     ZM  Zoom Video Communications Inc. Class A Common ...   69.350
# 3718    ZTO  ZTO Express (Cayman) Inc. American Depositary ...   24.005
# 3720    ZTS                   Zoetis Inc. Class A Common Stock  168.160
# 3721   ZUMZ                           Zumiez Inc. Common Stock   23.230
# 3726   ZYXI                            Zynex Inc. Common Stock   12.600
#
#         Volume     P/E  PE Percentile    P/B  PB Percentile   P/S  \
# 0       674929   30.97            NaN   7.25            NaN  5.92
# 5       349004   26.20            NaN   0.62            NaN  0.21
# 7        78945   65.19            NaN   8.28            NaN  5.70
# 8       480281   16.79            NaN   3.07            NaN  0.76
# 9     19134996   25.03            NaN  41.11            NaN  6.16
# ...        ...     ...            ...    ...            ...   ...
# 3715   1758193  204.76            NaN   3.28            NaN  4.82
# 3718   7674522   21.36            NaN   2.63            NaN  3.95
# 3720    318989   37.32            NaN  17.63            NaN  9.76
# 3721     81291   10.85            NaN   1.19            NaN  0.46
# 3726     73928   27.28            NaN   7.57            NaN  3.39
#
#       PS Percentile  EV/EBITDA  EV/EBITDA Percentile  EV/Revenue  \
# 0               NaN      21.36                   NaN        6.12
# 5               NaN       1.91                   NaN        0.56
# 7               NaN      30.20                   NaN        5.55
# 8               NaN      11.80                   NaN        1.04
# 9               NaN      18.68                   NaN        6.17
# ...             ...        ...                   ...         ...
# 3715            NaN      45.80                   NaN        3.42
# 3718            NaN       2.44                   NaN        0.56
# 3720            NaN      24.58                   NaN       10.17
# 3721            NaN       6.35                   NaN        0.55
# 3726            NaN      18.29                   NaN        3.33
#
#       EV/Revenue Percentile  RV Score
# 0                       NaN       NaN
# 5                       NaN       NaN
# 7                       NaN       NaN
# 8                       NaN       NaN
# 9                       NaN       NaN
# ...                     ...       ...
# 3715                    NaN       NaN
# 3718                    NaN       NaN
# 3720                    NaN       NaN
# 3721                    NaN       NaN
# 3726                    NaN       NaN
#
# [1855 rows x 15 columns]

# %%
stocks_less_15 = stocks_stats_without_NaN[stocks_stats_without_NaN['Price'] <= 15]
stocks_less_10 = stocks_stats_without_NaN[stocks_stats_without_NaN['Price'] <= 10]

stocks_greater_10 = stocks_stats_without_NaN[(stocks_stats_without_NaN['Price'] >= 10) &
                                            (stocks_stats_without_NaN['Price'] <= 30)]

stocks_less_5 = stocks_stats_without_NaN[stocks_stats_without_NaN['Price'] <= 5]
stocks_less_3 = stocks_stats_without_NaN[stocks_stats_without_NaN['Price'] <= 3]

stocks_30_50 = stocks_stats_without_NaN[(stocks_stats_without_NaN['Price'] >= 30) &
                                            (stocks_stats_without_NaN['Price'] <= 50)]

# %%
stocks_greater_10
# Out:
#      Symbol                                               Name   Price  \
# 5       AAN         Aarons Holdings Company Inc. Common Stock   12.700
# 38      ACI     Albertsons Companies Inc. Class A Common Stock  19.990
# 39     ACIW                    ACI Worldwide Inc. Common Stock  26.015
# 52      ACU              Acme United Corporation. Common Stock  24.430
# 81      AEO        American Eagle Outfitters Inc. Common Stock  14.460
# ...     ...                                                ...     ...
# 3710     ZI             ZoomInfo Technologies Inc Common Stock  24.370
# 3713    ZIP             ZipRecruiter Inc. Class A Common Stock  16.940
# 3718    ZTO  ZTO Express (Cayman) Inc. American Depositary ...  24.005
# 3721   ZUMZ                           Zumiez Inc. Common Stock  23.230
# 3726   ZYXI                            Zynex Inc. Common Stock  12.600
#
#        Volume     P/E  PE Percentile    P/B  PB Percentile   P/S  \
# 5      349004   26.20            NaN   0.62            NaN  0.21
# 38    2396675    8.04            NaN  13.82            NaN  0.13
# 39     194138   20.81            NaN   2.43            NaN  2.07
# 52        908   15.94            NaN   1.11            NaN  0.48
# 81    2748014   23.16            NaN   1.81            NaN  0.58
# ...       ...     ...            ...    ...            ...   ...
# 3710   936785  151.06            NaN   4.30            NaN  8.88
# 3713   143523   33.35            NaN  65.49            NaN  2.28
# 3718  7674522   21.36            NaN   2.63            NaN  3.95
# 3721    81291   10.85            NaN   1.19            NaN  0.46
# 3726    73928   27.28            NaN   7.57            NaN  3.39
#
#       PS Percentile  EV/EBITDA  EV/EBITDA Percentile  EV/Revenue  \
# 5               NaN       1.91                   NaN        0.56
# 38              NaN       4.40                   NaN        0.29
# 39              NaN       9.40                   NaN        2.72
# 52              NaN      11.51                   NaN        0.79
# 81              NaN       9.50                   NaN        0.88
# ...             ...        ...                   ...         ...
# 3710            NaN      31.94                   NaN        9.60
# 3713            NaN      16.46                   NaN        2.06
# 3718            NaN       2.44                   NaN        0.56
# 3721            NaN       6.35                   NaN        0.55
# 3726            NaN      18.29                   NaN        3.33
#
#       EV/Revenue Percentile  RV Score
# 5                       NaN       NaN
# 38                      NaN       NaN
# 39                      NaN       NaN
# 52                      NaN       NaN
# 81                      NaN       NaN
# ...                     ...       ...
# 3710                    NaN       NaN
# 3713                    NaN       NaN
# 3718                    NaN       NaN
# 3721                    NaN       NaN
# 3726                    NaN       NaN
#
# [464 rows x 15 columns]

# %% [markdown]
# ## Calculating Value Percentiles
#
# We now need to calculate value score percentiles for every stock in the universe. More specifically, we need to calculate percentile scores for the following metrics for every stock:
#
# * Price-to-earnings ratio
# * Price-to-book ratio
# * Price-to-sales ratio
# * EV/EBITDA
# * EV/GP
#
# Here's how we'll do this:

# %%
rv_dataframe = stocks_stats_without_NaN
rv_dataframe = rv_dataframe.reset_index().drop(columns='index')
metrics = {
    'P/E':'PE Percentile',
    'P/B':'PB Percentile',
    'P/S':'PS Percentile',
    'EV/EBITDA':'EV/EBITDA Percentile',
    'EV/Revenue':'EV/Revenue Percentile'
}
for metric in metrics.keys():
    for row in rv_dataframe.index:
        rv_dataframe.loc[row, metrics[metric]] \
            = stats.percentileofscore(rv_dataframe[metric], rv_dataframe.loc[row, metric])
        
rv_dataframe
# Out:
#      Symbol                                               Name    Price  \
# 0         A             Agilent Technologies Inc. Common Stock  140.210
# 1       AAN         Aarons Holdings Company Inc. Common Stock    12.700
# 2      AAON                             AAON Inc. Common Stock   90.285
# 3       AAP                            Advance Auto Parts Inc.  137.650
# 4      AAPL                            Apple Inc. Common Stock  144.485
# ...     ...                                                ...      ...
# 1850     ZM  Zoom Video Communications Inc. Class A Common ...   69.350
# 1851    ZTO  ZTO Express (Cayman) Inc. American Depositary ...   24.005
# 1852    ZTS                   Zoetis Inc. Class A Common Stock  168.160
# 1853   ZUMZ                           Zumiez Inc. Common Stock   23.230
# 1854   ZYXI                            Zynex Inc. Common Stock   12.600
#
#         Volume     P/E  PE Percentile    P/B  PB Percentile   P/S  \
# 0       674929   30.97      72.884097   7.25      87.412399  5.92
# 1       349004   26.20      65.929919   0.62       5.768194  0.21
# 2        78945   65.19      90.134771   8.28      89.326146  5.70
# 3       480281   16.79      44.150943   3.07      63.584906  0.76
# 4     19134996   25.03      63.773585  41.11      98.706199  6.16
# ...        ...     ...            ...    ...            ...   ...
# 1850   1758193  204.76      97.466307   3.28      66.576819  4.82
# 1851   7674522   21.36      56.442049   2.63      56.495957  3.95
# 1852    318989   37.32      78.733154  17.63      96.307278  9.76
# 1853     81291   10.85      27.708895   1.19      20.134771  0.46
# 1854     73928   27.28      67.897574   7.57      88.221024  3.39
#
#       PS Percentile  EV/EBITDA  EV/EBITDA Percentile  EV/Revenue  \
# 0         87.493261      21.36             87.008086        6.12
# 1          4.016173       1.91             10.458221        0.56
# 2         86.846361      30.20             93.746631        5.55
# 3         25.849057      11.80             57.681941        1.04
# 4         88.301887      18.68             81.617251        6.17
# ...             ...        ...                   ...         ...
# 1850      83.477089      45.80             97.142857        3.42
# 1851      78.921833       2.44             12.048518        0.56
# 1852      94.555256      24.58             90.296496       10.17
# 1853      14.312668       6.35             28.409704        0.55
# 1854      74.204852      18.29             80.646900        3.33
#
#       EV/Revenue Percentile  RV Score
# 0                 85.902965       NaN
# 1                 15.256065       NaN
# 2                 83.450135       NaN
# 3                 30.970350       NaN
# 4                 86.145553       NaN
# ...                     ...       ...
# 1850              70.000000       NaN
# 1851              15.256065       NaN
# 1852              93.315364       NaN
# 1853              14.770889       NaN
# 1854              69.002695       NaN
#
# [1855 rows x 15 columns]

# %% [markdown]
# ## Calculating the RV Score
# We'll now calculate our RV Score (which stands for Robust Value), which is the value score that we'll use to filter for stocks in this investing strategy.
#
# The RV Score will be the arithmetic mean of the 4 percentile scores that we calculated in the last section.
#
# To calculate arithmetic mean, we will use the mean function from Python's built-in statistics module.

# %%
from statistics import mean

for row in rv_dataframe.index:
    value_percentiles = []
    for metric in metrics.keys():
        value_percentiles.append(rv_dataframe.loc[row, metrics[metric]])
    rv_dataframe.loc[row, 'RV Score'] = mean(value_percentiles)
rv_dataframe
# Out:
#      Symbol                                               Name    Price  \
# 0         A             Agilent Technologies Inc. Common Stock  140.210
# 1       AAN         Aarons Holdings Company Inc. Common Stock    12.700
# 2      AAON                             AAON Inc. Common Stock   90.285
# 3       AAP                            Advance Auto Parts Inc.  137.650
# 4      AAPL                            Apple Inc. Common Stock  144.485
# ...     ...                                                ...      ...
# 1850     ZM  Zoom Video Communications Inc. Class A Common ...   69.350
# 1851    ZTO  ZTO Express (Cayman) Inc. American Depositary ...   24.005
# 1852    ZTS                   Zoetis Inc. Class A Common Stock  168.160
# 1853   ZUMZ                           Zumiez Inc. Common Stock   23.230
# 1854   ZYXI                            Zynex Inc. Common Stock   12.600
#
#         Volume     P/E  PE Percentile    P/B  PB Percentile   P/S  \
# 0       674929   30.97      72.884097   7.25      87.412399  5.92
# 1       349004   26.20      65.929919   0.62       5.768194  0.21
# 2        78945   65.19      90.134771   8.28      89.326146  5.70
# 3       480281   16.79      44.150943   3.07      63.584906  0.76
# 4     19134996   25.03      63.773585  41.11      98.706199  6.16
# ...        ...     ...            ...    ...            ...   ...
# 1850   1758193  204.76      97.466307   3.28      66.576819  4.82
# 1851   7674522   21.36      56.442049   2.63      56.495957  3.95
# 1852    318989   37.32      78.733154  17.63      96.307278  9.76
# 1853     81291   10.85      27.708895   1.19      20.134771  0.46
# 1854     73928   27.28      67.897574   7.57      88.221024  3.39
#
#       PS Percentile  EV/EBITDA  EV/EBITDA Percentile  EV/Revenue  \
# 0         87.493261      21.36             87.008086        6.12
# 1          4.016173       1.91             10.458221        0.56
# 2         86.846361      30.20             93.746631        5.55
# 3         25.849057      11.80             57.681941        1.04
# 4         88.301887      18.68             81.617251        6.17
# ...             ...        ...                   ...         ...
# 1850      83.477089      45.80             97.142857        3.42
# 1851      78.921833       2.44             12.048518        0.56
# 1852      94.555256      24.58             90.296496       10.17
# 1853      14.312668       6.35             28.409704        0.55
# 1854      74.204852      18.29             80.646900        3.33
#
#       EV/Revenue Percentile   RV Score
# 0                 85.902965  84.140162
# 1                 15.256065  20.285714
# 2                 83.450135  88.700809
# 3                 30.970350  44.447439
# 4                 86.145553  83.708895
# ...                     ...        ...
# 1850              70.000000  82.932615
# 1851              15.256065  43.832884
# 1852              93.315364  90.641509
# 1853              14.770889  21.067385
# 1854              69.002695  75.994609
#
# [1855 rows x 15 columns]

# %% [markdown]
# ## Selecting the 50 Best Value Stocks¶
#
# As before, we can identify the 50 best value stocks in our universe by sorting the DataFrame on the RV Score column and dropping all but the top 50 entries.

# %%
rv_dataframe.sort_values('RV Score', ascending=True, inplace=True)
rv_dataframe.reset_index(inplace=True, drop=True)
# rv_dataframe = rv_dataframe[:50]
rv_dataframe = rv_dataframe[rv_dataframe['Volume'] > 100000]

# %%
price_30_to_50 = rv_dataframe
# price_10_To_30 = rv_dataframe

# %%
rv_dataframe.to_csv('Mar_3_pred.csv', index=False)

# %%
price_30_to_50
# Out:
#    Symbol                                               Name    Price  \
# 0     JXN       Jackson Financial Inc. Class A Common Stock   41.5900
# 1     PBF               PBF Energy Inc. Class A Common Stock  46.7100
# 2       X       United States Steel Corporation Common Stock  30.8800
# 3      TX  Ternium S.A. Ternium S.A. American Depositary ...  44.4901
# 5     WBA         Walgreens Boots Alliance Inc. Common Stock  34.9925
# 6     KBH                               KB Home Common Stock  34.6000
# 7     MDC                  M.D.C. Holdings Inc. Common Stock  36.1200
# 10   TMHC      Taylor Morrison Home Corporation Common Stock  35.3850
# 14     GM                General Motors Company Common Stock  38.6800
# 16    WRK                      Westrock Company Common Stock  31.9559
# 17    CPE              Callon Petroleum Company Common Stock  39.7500
# 19   EQNR                                        Equinor ASA  31.0900
# 23    NRG                       NRG Energy Inc. Common Stock  32.7050
# 31     SM                     SM Energy Company Common Stock  30.6600
# 32    OVV                                  Ovintiv Inc. (DE)  45.6700
# 35    BFH         Bread Financial Holdings Inc. Common Stock  40.1300
# 36     FL                                   Foot Locker Inc.  43.5500
# 37   PLCE           Children's Place Inc. (The) Common Stock  41.9950
# 38    EQT                       EQT Corporation Common Stock  33.3350
# 40     SU                   Suncor Energy  Inc. Common Stock  34.6600
# 42   ROCC        Ranger Oil Corporation Class A Common Stock  42.8000
# 44    DCP                    DCP Midstream  LP Common Units   41.7600
# 47    CVI                       CVR Energy Inc. Common Stock  33.0600
#
#      Volume    P/E  PE Percentile   P/B  PB Percentile   P/S  PS Percentile  \
# 0    632419   0.55       0.346021  0.39       0.346021  0.24       3.114187
# 1    670916   2.05       2.422145  1.23      13.840830  0.13       1.038062
# 2   2312382   3.34       3.460208  0.68       2.422145  0.40       9.342561
# 3    104218   4.90       8.650519  0.73       3.114187  0.53      15.570934
# 5   1409146   5.98      10.380623  1.48      23.529412  0.23       2.768166
# 6    358430   3.84       5.536332  0.80       5.536332  0.45      11.245675
# 7    143074   4.82       8.131488  0.87       8.131488  0.47      11.937716
# 10   166842   3.97       5.882353  0.84       6.747405  0.51      14.878893
# 14  4063152   6.32      11.072664  0.80       5.536332  0.36       7.266436
# 16   379068  10.10      25.259516  0.69       2.768166  0.38       7.958478
# 17   364908   2.04       2.076125  0.79       4.671280  0.76      26.643599
# 19  1099067   3.38       3.806228  1.76      36.159170  0.65      22.491349
# 23   990583   6.39      11.764706  1.98      44.290657  0.25       3.806228
# 31   419561   3.41       4.152249  1.21      12.975779  1.13      36.505190
# 32  1509075   3.21       2.768166  1.43      20.934256  0.94      32.525952
# 35   168765   4.82       8.131488  0.84       6.747405  0.55      16.262976
# 36   442598   9.70      24.221453  1.24      14.186851  0.48      12.975779
# 37   135460   6.66      13.494810  2.45      57.785467  0.33       6.055363
# 38  1346790   7.60      16.262976  1.07      11.072664  1.11      35.467128
# 40  6510888   7.18      15.224913  1.59      27.854671  1.12      35.986159
# 42   410297   4.28       6.920415  1.80      38.062284  0.82      28.892734
# 44   185641   8.87      20.415225  1.45      21.799308  0.58      17.993080
# 47   264197   7.27      15.570934  6.33      89.619377  0.31       4.844291
#
#     EV/EBITDA  EV/EBITDA Percentile  EV/Revenue  EV/Revenue Percentile  \
# 0       -2.17              3.114187        0.16               2.941176
# 1        1.50              6.574394        0.14               1.903114
# 2        1.80              6.920415        0.36               6.055363
# 3        1.92              7.266436        0.39               6.574394
# 5      -22.91              1.730104        0.47               8.477509
# 6        4.11             13.494810        0.65              15.570934
# 7        3.87             12.456747        0.54              11.591696
# 10       3.88             12.802768        0.70              17.647059
# 14       5.80             20.761246        0.88              25.778547
# 16       5.83             21.107266        0.80              23.010381
# 17       2.67              9.342561        1.45              37.543253
# 19       0.96              5.536332        0.56              12.975779
# 23       5.28             17.647059        0.49               9.342561
# 31       2.29              7.958478        1.45              37.543253
# 32       3.11             10.034602        1.24              34.256055
# 35       6.08             22.491349        1.92              48.442907
# 36       8.00             31.833910        0.79              22.145329
# 37       5.69             19.377163        0.57              13.494810
# 38       3.80             11.591696        1.34              36.332180
# 40       2.49              8.996540        0.95              27.162630
# 42       2.01              7.612457        1.26              34.948097
# 44       8.07             32.525952        0.91              26.297578
# 47       3.80             11.591696        0.41               7.266436
#
#      RV Score
# 0    1.972318
# 1    5.155709
# 2    5.640138
# 3    8.235294
# 5    9.377163
# 6   10.276817
# 7   10.449827
# 10  11.591696
# 14  14.083045
# 16  16.020761
# 17  16.055363
# 19  16.193772
# 23  17.370242
# 31  19.826990
# 32  20.103806
# 35  20.415225
# 36  21.072664
# 37  22.041522
# 38  22.145329
# 40  23.044983
# 42  23.287197
# 44  23.806228
# 47  25.778547

# %%
All = rv_dataframe

# %%
All[50:100]
# Out:
#     Symbol                                               Name     Price  \
# 111    PBR   Petroleo Brasileiro S.A.- Petrobras Common Stock   10.9800
# 125    ASX  ASE Technology Holding Co. Ltd. American Depos...    7.2950
# 127    VLO             Valero Energy Corporation Common Stock  139.1600
# 129    BTU           Peabody Energy Corporation Common Stock    27.6042
# 131    MPC        Marathon Petroleum Corporation Common Stock  128.9100
# 133     GM                General Motors Company Common Stock   38.6800
# 135    VET              Vermilion Energy Inc. Common (Canada)   13.6700
# 140   AVIR             Atea Pharmaceuticals Inc. Common Stock    3.3950
# 143   EQNR                                        Equinor ASA   31.0900
# 151    TSN                      Tyson Foods Inc. Common Stock   58.5250
# 153    WRK                      Westrock Company Common Stock   31.9559
# 155    CPE              Callon Petroleum Company Common Stock   39.7500
# 158   SBOW               SilverBow Resorces Inc. Common Stock   28.1000
# 159    DBI          Designer Brands Inc. Class A Common Stock    9.8250
# 160  LTRPA  Liberty TripAdvisor Holdings Inc. Series A Com...    1.0500
# 164    PAA  Plains All American Pipeline L.P. Common Units...   13.3000
# 166     BG                        Bunge Limited Bunge Limited   97.4700
# 168   CMRX                         Chimerix Inc. Common Stock    1.6250
# 169     DK                Delek US Holdings Inc. Common Stock   25.5500
# 170   CRBG             Corebridge Financial Inc. Common Stock   20.4600
# 171    BTE                   Baytex Energy Corp Common Shares    4.0300
# 172  CRESY  Cresud S.A.C.I.F. y A. American Depositary Shares    7.5300
# 174   CCRN  Cross Country Healthcare Inc. Common Stock $0....   26.1400
# 177   DISH      DISH Network Corporation Class A Common Stock   10.7400
# 178    TTE                                   TotalEnergies SE   62.5800
# 179    TOL                    Toll Brothers Inc. Common Stock   58.5600
# 181    SXC                   SunCoke Energy Inc. Common Stock    9.9650
# 182    DXC               DXC Technology Company Common Stock    27.7300
# 183    TWI         Titan International Inc. (DE) Common Stock   12.8600
# 184   LUMN               Lumen Technologies Inc. Common Stock    3.1600
# 185    NRG                       NRG Energy Inc. Common Stock   32.7050
# 192    AAN         Aarons Holdings Company Inc. Common Stock    12.7000
# 193    IMO                  Imperial Oil Limited Common Stock   50.9000
# 195   VIPS  Vipshop Holdings Limited American Depositary S...   15.0100
# 197     TA         TravelCenters of America Inc. Common Stock   84.4300
# 200   REZI            Resideo Technologies Inc. Common Stock    18.5300
# 202   SKYW                          SkyWest Inc. Common Stock   19.7600
# 204    CPG  Crescent Point Energy Corporation Ordinary Sha...    7.2100
# 205     TK                    Teekay Corporation Common Stock    6.2450
# 208    LEN            Lennar Corporation Class A Common Stock   94.8600
# 210    CLF                 Cleveland-Cliffs Inc. Common Stock   21.7400
# 213    CMC             Commercial Metals Company Common Stock   52.3050
# 215    CHK         Chesapeake Energy Corporation Common Stock   81.2000
# 216    PHM                       PulteGroup Inc. Common Stock   53.6800
# 218    PPC           Pilgrim's Pride Corporation Common Stock   23.9500
# 219    ODP                   The ODP Corporation Common Stock   50.8350
# 223   CEIX                   CONSOL Energy Inc. Common Stock    59.9000
# 227   SWBI            Smith & Wesson Brands Inc. Common Stock   10.6850
# 230    CVE                    Cenovus Energy Inc Common Stock   18.9900
# 232   EBIX                             Ebix Inc. Common Stock   17.2550
#
#        Volume    P/E  PE Percentile   P/B  PB Percentile   P/S  PS Percentile  \
# 111  17821137   2.12       3.153639  1.05      16.495957  0.61      20.592992
# 125   1887640   7.88      19.649596  1.56      32.398922  0.71      23.719677
# 127   1138475   4.54       9.164420  2.08      45.956873  0.30       7.574124
# 129    710049   3.36       5.876011  1.24      22.075472  0.88      30.512129
# 131    937805   4.42       8.760108  1.99      44.070081  0.36      10.107817
# 133   4063152   6.32      15.013477  0.80       9.811321  0.36      10.107817
# 135    647392   2.50       3.881402  1.06      16.819407  0.87      30.161725
# 140    151033  11.38      28.894879  0.49       3.665768  1.70      52.398922
# 143   1099067   3.38       5.983827  1.76      37.789757  0.65      21.805930
# 151   1066514   8.80      21.832884  1.07      17.088949  0.40      11.725067
# 153    379068  10.10      25.606469  0.69       6.873315  0.38      10.943396
# 155    364908   2.04       3.018868  0.79       9.433962  0.76      25.849057
# 158    285789   1.36       2.048518  0.85      11.455526  0.62      20.943396
# 159    292985   5.45      12.129380  1.62      34.150943  0.21       4.016173
# 160    260223   2.74       4.312668  4.55      76.819407  0.06       0.485175
# 164   1326246  11.13      28.409704  0.92      13.719677  0.16       2.668464
# 166    349215   9.09      22.587601  1.55      32.021563  0.22       4.366577
# 168   1022027   0.91       1.239892  0.50       4.016173  4.20      80.161725
# 169    808604   7.19      17.547170  1.83      39.838275  0.09       0.862534
# 170    479072   1.63       2.479784  1.61      33.881402  0.50      16.172507
# 171   1195890   3.56       6.415094  0.97      14.878706  1.05      35.579515
# 172    112724  16.74      43.962264  0.72       7.574124  1.15      38.032345
# 174    267674   5.31      11.644205  2.15      47.924528  0.36      10.107817
# 177   5858201   3.10       5.148248  0.33       1.698113  0.43      13.126685
# 178    675948   7.89      19.730458  1.36      26.253369  0.61      20.592992
# 179    720738   5.19      11.266846  1.05      16.495957  0.66      22.156334
# 181    170424   8.34      20.727763  1.41      27.762803  0.43      13.126685
# 182    347805   9.63      24.366577  1.37      26.630728  0.44      13.557951
# 183    202664   4.66       9.433962  2.13      47.385445  0.38      10.943396
# 184  14851045  10.49      26.388140  0.33       1.698113  0.20       3.719677
# 185    990583   6.39      15.256065  1.98      43.773585  0.25       5.336927
# 192    349004  26.20      65.929919  0.62       5.768194  0.21       4.016173
# 193    143551   5.86      13.315364  1.75      37.277628  0.75      25.363881
# 195   2716517  10.74      27.439353  1.89      41.428571  0.66      22.156334
# 197    473709   9.62      24.285714  1.54      31.752022  0.12       1.428571
# 200    226775   9.90      25.013477  1.09      17.574124  0.44      13.557951
# 202    123091  13.24      34.150943  0.41       2.560647  0.32       8.463612
# 204   2881601   2.67       4.204852  0.74       8.221024  1.44      46.522911
# 205   1045800  17.22      45.256065  0.98      15.067385  0.54      17.547170
# 208    585761   6.08      14.312668  1.15      19.272237  0.82      28.328841
# 210   2841357   8.40      20.943396  1.42      28.059299  0.49      15.606469
# 213    307407   5.06      10.781671  1.69      35.633423  0.69      22.884097
# 215    279727   2.44       3.773585  1.20      20.566038  1.04      35.094340
# 216    522139   4.97      10.485175  1.38      27.008086  0.80      27.601078
# 218    117138   7.65      18.814016  1.97      43.504043  0.33       9.002695
# 219    162201  13.30      34.285714  1.45      28.948787  0.28       6.495957
# 223    630607   4.19       7.978437  1.63      34.447439  0.86      29.811321
# 227    101857   6.18      14.663073  1.34      25.552561  0.88      30.512129
# 230   2080033   7.94      19.838275  1.79      38.733154  0.71      23.719677
# 232    132861   7.57      18.544474  0.89      12.533693  0.52      16.981132
#
#      EV/EBITDA  EV/EBITDA Percentile  EV/Revenue  EV/Revenue Percentile  \
# 111       1.73              9.757412        0.97              29.164420
# 125       0.14              6.280323        0.03               2.533693
# 127       3.09             14.231806        0.32               7.870620
# 129       1.77             10.000000        0.62              17.169811
# 131       2.86             13.369272        0.40               9.811321
# 133       5.80             25.795148        0.88              25.606469
# 135       1.49              9.272237        0.91              26.792453
# 140     -11.09              1.994609       -1.77               0.646900
# 143       0.96              8.544474        0.56              15.256065
# 151       6.08             27.142857        0.54              14.366577
# 153       5.83             26.010782        0.80              22.857143
# 155       2.67             12.857143        1.45              41.293801
# 158       2.63             12.722372        1.65              45.876011
# 159       6.45             29.056604        0.53              13.935310
# 160       0.74              7.628032        0.13               4.258760
# 164       9.03             42.075472        0.29               7.304582
# 166       6.51             29.380054        0.28               7.035040
# 168       1.90             10.404313       -4.36               0.323450
# 169       7.18             32.749326        0.20               5.444744
# 170       2.53             12.560647        1.05              31.428571
# 171       1.82             10.188679        0.98              29.487871
# 172      -0.26              4.797844        0.02               2.237197
# 174       4.01             17.789757        0.40               9.811321
# 177       7.12             32.425876        1.64              45.606469
# 178       2.89             13.477089        0.65              18.167116
# 179       5.10             23.045822        0.87              25.256065
# 181       4.29             19.083558        0.64              17.897574
# 182       3.48             15.363881        0.67              18.787062
# 183       4.02             17.843666        0.51              13.153639
# 184       6.44             28.975741        1.32              38.032345
# 185       5.28             23.611860        0.49              12.398922
# 192       1.91             10.458221        0.56              15.256065
# 193       2.57             12.668464        0.51              13.153639
# 195       0.75              7.762803        0.06               3.180593
# 197       8.24             37.574124        0.28               7.035040
# 200       6.82             30.781671        0.61              16.819407
# 202       5.63             24.797844        1.15              34.204852
# 204       1.26              8.840970        1.26              36.738544
# 205       1.97             10.619946        0.58              16.145553
# 208       4.15             18.517520        0.85              24.474394
# 210       4.91             22.156334        0.66              18.436658
# 213       3.73             16.361186        0.74              21.132075
# 215       2.52             12.452830        1.22              35.714286
# 216       3.99             17.735849        0.86              24.851752
# 218       5.51             24.420485        0.50              12.776280
# 219       6.97             31.671159        0.31               7.654987
# 223       2.40             11.725067        0.89              26.037736
# 227       3.60             15.795148        0.86              24.851752
# 230       2.95             13.746631        0.57              15.714286
# 232       7.20             32.938005        1.04              30.970350
#
#       RV Score
# 111  15.832884
# 125  16.916442
# 127  16.959569
# 129  17.126685
# 131  17.223720
# 133  17.266846
# 135  17.385445
# 140  17.520216
# 143  17.876011
# 151  18.431267
# 153  18.458221
# 155  18.490566
# 158  18.609164
# 159  18.657682
# 160  18.700809
# 164  18.835580
# 166  19.078167
# 168  19.229111
# 169  19.288410
# 170  19.304582
# 171  19.309973
# 172  19.320755
# 174  19.455526
# 177  19.601078
# 178  19.644205
# 179  19.644205
# 181  19.719677
# 182  19.741240
# 183  19.752022
# 184  19.762803
# 185  20.075472
# 192  20.285714
# 193  20.355795
# 195  20.393531
# 197  20.415094
# 200  20.749326
# 202  20.835580
# 204  20.905660
# 205  20.927224
# 208  20.981132
# 210  21.040431
# 213  21.358491
# 215  21.520216
# 216  21.536388
# 218  21.703504
# 219  21.811321
# 223  22.000000
# 227  22.274933
# 230  22.350404
# 232  22.393531
